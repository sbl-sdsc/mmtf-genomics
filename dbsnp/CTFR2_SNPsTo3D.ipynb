# %% [markdown]
# ## Find Missense Mutations in PDB
# This notebook is a prototype for visualizing the positions of missense mutations from [dbSNP](https://www.ncbi.nlm.nih.gov/projects/SNP/) (GRCh37 build) for cases where a protein structure contains the mutated amino acid.

# %%
import warnings
warnings.filterwarnings("ignore") # numpy version issue?
from pyspark.sql import Row, SparkSession
from pyspark.sql.functions import collect_set, collect_list, concat_ws
from mmtfPyspark.datasets import dbSnpDataset
import pandas as pd
from ipywidgets import interact, IntSlider, widgets
from IPython.display import display
import py3Dmol

# %%
cf = pd.df = pd.read_excel('https://www.cftr2.org/sites/default/files/CFTR2_8December2017_2.xlsx', skiprows=10,skipfooter=5,na_values=['not found','nan','NaN'])

# %%
cf['rsID'] = cf['rsID'].astype(str)
#cf['Variant final determination 17 March 2017 (previous version)'] = cf['Variant final determination 17 March 2017 (previous version)'].astype(str)
cf['snpId'] = cf['rsID'].map(lambda s: s.replace('rs', ''))
# cf.ix[0].astype(str)
# cf.ix[1].astype(str)
# cf.ix[2].astype(str)
# cf.ix[7].astype(str)
# cf.ix[8].astype(str)
# cf.ix[9].astype(str)
cf['Variant final determination\n17 March 2017\n(previous version)'] = cf['Variant final determination\n17 March 2017\n(previous version)'].astype(str)
cf.dtypes
# Out:
# Variant cDNA name\n(ordered 5' to 3')                                               object
# Variant protein name                                                                object
# Variant legacy name                                                                 object
# rsID                                                                                object
# # alleles in CFTR2                                                                   int64
# Allele frequency in CFTR2\n(of 142,036 identified variants)*                       float64
# % pancreatic insufficient (patients with variant in trans with ACMG-PI variant)    float64
# Variant final determination\n17 March 2017\n(previous version)                      object
# Variant final determination\n6 December 2017\n(current version)                     object
# Change from previous version?                                                       object
# snpId                                                                               object
# dtype: object

# %%
cf.head(500)
# Out:
#                  Variant cDNA name\n(ordered 5' to 3') Variant protein name  \
# 0                                         c.-9_14del23      No protein name
# 1                               c.(?_1)_(53+1_54-1)del       p.Glu2GlyfsX17
# 2                                               c.1A>G            p.Met1Val
# 3                                               c.4C>T              p.Gln2X
# 4                                              c.11C>A              p.Ser4X
# 5                                              c.14C>T            p.Pro5Leu
# 6                                             c.50delT       p.Phe17SerfsX8
# 7                       c.(53+1_54-1)_(164+1_165-1)del      No protein name
# 8                       c.(53+1_54-1)_(489+1_490-1)del      No protein name
# 9                                            c.53+1G>T      No protein name
# 10                          c.54-5940_273+10250del21kb      p.Ser18ArgfsX16
# 11                                             c.57G>A             p.Trp19X
# 12                                             c.79G>T             p.Gly27X
# 13                                             c.88C>T             p.Gln30X
# 14                                             c.91C>T           p.Arg31Cys
# 15                                             c.92G>T           p.Arg31Leu
# 16                                            c.115C>T             p.Gln39X
# 17                                           c.137C>A            p.Ala46Asp
# 18                                          c.164+1G>A      No protein name
# 19                                          c.164+1G>T      No protein name
# 20   c.(164+1_165-1)_(1584_+1_1585-1)del(2619+1_262...      No protein name
# 21                                          c.164+2T>C      No protein name
# 22                                   c.164+3_164+4insT      No protein name
# 23                                          c.165-3C>T      No protein name
# 24                                          c.165-1G>A      No protein name
# 25                                           c.166G>A            p.Glu56Lys
# 26                                            c.169T>G           p.Trp57Gly
# 27                                c.170G>A or c.171G>A             p.Trp57X
# 28                                      c.174_175insA       p.Arg59LysfsX10
# 29                                    c.174_177delTAGA      p.Asp58GlufsX32
# ..                                                 ...                  ...
# 344                                        c.3873+1G>A      No protein name
# 345               c.(3873+1_3874-1)_(3963+1_3964-1)del      No protein name
# 346                                        c.3873+2T>C      No protein name
# 347                                 c.3882_3885delTATT    p.Ile1295PhefsX32
# 348                                        c.3883delA     p.Ile1295PhefsX33
# 349                                    c.3884_3885insT    p.Ser1297PhefsX5
# 350                                         c.3889dupT     p.Ser1297PhefsX5
# 351                                    c.3890_3891insT     p.Gly1298TrpfsX4
# 352                                         c.3908delA    p.Asn1303ThrfsX25
# 353                                          c.3909C>G         p.Asn1303Lys
# 354                                          c.3937C>T           p.Gln1313X
# 355                        c.(3963+1_3964-1)_(*1_?)del      No protein name
# 356                              c.3964-78_4242+577del      No protein name
# 357                                          c.3988C>T           p.Gln1330X
# 358                                          c.4004T>C         p.Leu1335Pro
# 359                              c.4036_4042delCTAAGCC     p.Leu1346MetfsX6
# 360                                          c.4046G>A        p.Gly1349Asp
# 361                            c.4077_4080delTGTTinsAA      No protein name
# 362                                    c.4086_4087insT           p.Lys1363X
# 363                                         c.4111G>T           p.Glu1371X
# 364                                c.4127_4131delTGGAT     p.Leu1376SerfsX8
# 365                                          c.4144C>T           p.Gln1382X
# 366                                    c.4147_4148insA     p.Ile1383AsnfsX3
# 367                                  c.4196_4197delTC           p.Cys1400X
# 368                                          c.4231C>T           p.Gln1411X
# 369                                         c.4234C>T           p.Gln1412X
# 370                                       c.4242+1G>T       No protein name
# 371                                        c.4242+1G>A      No protein name
# 372                                         c.4251delA    p.Glu1418ArgfsX14
# 373                                  c.4296_4297insGA    p.Ser1435GlyfsX14
#
#      Variant legacy name                        rsID  # alleles in CFTR2  \
# 0             124del23bp                 rs397508136                   6
# 1              CFTRdele1                         nan                   6
# 2                    M1V                 rs397508328                  26
# 3                    Q2X                 rs397508740                   5
# 4                    S4X                 rs397508173                  14
# 5                    P5L                 rs193922501                  60
# 6                182delT                 rs397508742                   9
# 7              CFTRdele2                         nan                  46
# 8            CFTRdele2-4                         nan                   4
# 9              185+1G->T                 rs397508746                   8
# 10           CFTRdele2,3                         nan                 417
# 11                  W19X                 rs397508762                   4
# 12                  G27X                 rs397508796                  10
# 13                  Q30X                 rs397508815                   3
# 14                  R31C                   rs1800073                  23
# 15                  R31L                 rs149353983                   7
# 16                  Q39X                 rs397508168                  47
# 17                  A46D                 rs151020603                   4
# 18             296+1G->A                 rs397508243                   3
# 19             296+1G->T                 rs397508243                   4
# 20   CFTRdele3-10,14b-16                         nan                   4
# 21             296+2T->C                 rs121908800                   3
# 22             296+3insT                 rs397508244                   4
# 23             297-3C->T                 rs200337193                   3
# 24             297-1G->A                 rs397508249                   5
# 25                  E56K                 rs397508256                   5
# 26                  W57G                 rs397508272                  10
# 10                                            0.996310
# 11                                            1.000000
# 12                                            1.000000
# 13                                            1.000000
# 14                                            0.300000
# 15                                            0.000000
# 16                                            1.000000
# 17                                            1.000000
# 18                                            1.000000
# 19                                            1.000000
# 20                                            1.000000
# 21                                            1.000000
# 22                                            0.500000
# 23                                            1.000000
# 24                                            1.000000
# 25                                            0.000000
# 26                                            1.000000
# 27                                            1.000000
# 28                                            0.937500
# 29                                            1.000000
# ..                                                 ...
# 344                                           1.000000
# 345                                           1.000000
# 346                                           0.266667
# 347                                           1.000000
# 348                                           0.666667
# 349                                           1.000000
# 350                                           1.000000
# 351                                           1.000000
# 352                                           1.000000
# 353                                           0.981595
# 354                                           1.000000
# 355                                           1.000000
# 356                                           0.962963
# 357                                           1.000000
# 358                                           0.615385
# 359                                           1.000000
# 360                                           0.875000
# 361                                           1.000000
# 362                                           1.000000
# 363                                           1.000000
# 364                                           1.000000
# 365                                           1.000000
# 366                                           1.000000
# 367                                           1.000000
# 368                                           1.000000
# 369                                           1.000000
# 370                                           0.928571
# 371                                           1.000000
# 372                                           0.384615
# 373                                           0.750000
#
#     Variant final determination\n17 March 2017\n(previous version)  \
# 0                                           CF-causing
# 1                                           CF-causing
# 2                                           CF-causing
# 3                                           CF-causing
# 4                                           CF-causing
# 5                                                  nan
# 6                                           CF-causing
# 7                                           CF-causing
# 8                                           CF-causing
# 9                                           CF-causing
# 10                                          CF-causing
# 11                                          CF-causing
# 12                                          CF-causing
# 13                                                 nan
# 14                                      Non CF-causing
# 15                                Unknown significance
# 16                                          CF-causing
# 17                                          CF-causing
# 18                                          CF-causing
# 19                                          CF-causing
# 20                                          CF-causing
# 21                                                 nan
# 22                                                 nan
# 23                                                 nan
# 24                                          CF-causing
# 25                                          CF-causing
# 26                                                 nan
# 27                                          CF-causing
# 28                                          CF-causing
# 29                                          CF-causing
# ..                                                 ...
# 344                                         CF-causing
# 345                                         CF-causing
# 346                                         CF-causing
# 347                                         CF-causing
# 348                                         CF-causing
# 349                                         CF-causing
# 350                                         CF-causing
# 351                                         CF-causing
# 352                                         CF-causing
# 353                                         CF-causing
# 354                                         CF-causing
# 355                                         CF-causing
# 356                                         CF-causing
# 357                                         CF-causing
# 358                                                nan
# 359                                                nan
# 360                                         CF-causing
# 361                                         CF-causing
# 362                                         CF-causing
# 363                                         CF-causing
# 364                                         CF-causing
# 365                                         CF-causing
# 366                                         CF-causing
# 367                                         CF-causing
# 368                                         CF-causing
# 369                                         CF-causing
# 370                                         CF-causing
# 371                                         CF-causing
# 372                                         CF-causing
# 373                                         CF-causing
#
#     Variant final determination\n6 December 2017\n(current version)  \
# 0                                           CF-causing
# 1                                           CF-causing
# 2                                           CF-causing
# 3                                           CF-causing
# 4                                           CF-causing
# 5                         Varying clinical consequence
# 6                                           CF-causing
# 7                                           CF-causing
# 8                                           CF-causing
# 9                                           CF-causing
# 10                                          CF-causing
# 11                                          CF-causing
# 12                                          CF-causing
# 13                                          CF-causing
# 14                                      Non CF-causing
# 15                                Unknown significance
# 16                                          CF-causing
# 17                                          CF-causing
# 18                                          CF-causing
# 19                                          CF-causing
# 20                                          CF-causing
# 21                                          CF-causing
# 22                                          CF-causing
# 23                                          CF-causing
# 24                                          CF-causing
# 25                                          CF-causing
# 26                                          CF-causing
# 27                                          CF-causing
# 28                                          CF-causing
# 29                                          CF-causing
# ..                                                 ...
# 344                                         CF-causing
# 345                                         CF-causing
# 346                                         CF-causing
# 347                                         CF-causing
# 348                                         CF-causing
# 349                                         CF-causing
# 350                                         CF-causing
# 351                                         CF-causing
# 352                                         CF-causing
# 353                                         CF-causing
# 354                                         CF-causing
# 355                                         CF-causing
# 356                                         CF-causing
# 357                                         CF-causing
# 358                                         CF-causing
# 359                                         CF-causing
# 360                                         CF-causing
# 361                                         CF-causing
# 362                                         CF-causing
# 363                                         CF-causing
# 364                                         CF-causing
# 365                                         CF-causing
# 366                                         CF-causing
# 367                                         CF-causing
# 368                                         CF-causing
# 369                                         CF-causing
# 370                                         CF-causing
# 371                                         CF-causing
# 372                                         CF-causing
# 373                                         CF-causing
#
#     Change from previous version?                   snpId
# 0                              No               397508136
# 1                              No                     nan
# 2                              No               397508328
# 3                              No               397508740
# 4                              No               397508173
# 5                             Yes               193922501
# 6                              No               397508742
# 7                              No                     nan
# 8                              No                     nan
# 9                              No               397508746
# 10                             No                     nan
# 11                             No               397508762
# 12                             No               397508796
# 13                            Yes               397508815
# 14                             No                 1800073
# 15                             No               149353983
# 16                             No               397508168
# 17                             No               151020603
# 18                             No               397508243
# 19                             No               397508243
# 20                             No                     nan
# 21                            Yes               121908800
# 22                            Yes               397508244
# 23                            Yes               200337193
# 24                             No               397508249
# 25                             No               397508256
# 26                            Yes               397508272
# 27                             No  397508279 or 121909025
# 28                             No               397508294
# 29                             No               397508295
# ..                            ...                     ...
# 344                            No               143570767
# 345                            No                     nan
# 346                            No               146795445
# 347                            No               397508628
# 348                            No               397508630
# 349                            No               121908808
# 350                            No               397508631
# 351                            No               397508631
# 352                            No               397508637
# 353                            No                80034486
# 354                            No               121909026
# 355                            No                     nan
# 356                            No                     nan
# 357                            No                     nan
# 358                           Yes               397508658
# 359                           Yes               397508662
# 360                            No               193922525
# 361                            No               397508668
# 362                            No               397508669
# 363                            No               397508675
# 364                            No                     nan
# 365                            No               397508684
# 366                            No               397508685
# 367                            No               397508693
# 368                            No               397508701
# 369                            No               397508702
# 370                            No               372227120
# 371                            No               372227120
# 372                            No               397508706
# 373                            No               397508709
#
# [374 rows x 11 columns]

# %% [markdown]
# ### Initialize Spark

# %%
spark = SparkSession.builder.master("local[4]").appName("CTFR2_SNPsTo3D").getOrCreate()

# %%
ctfr2 = spark.createDataFrame(cf)
ctfr2.printSchema()
# Out:
# root
#  |-- Variant cDNA name
# (ordered 5' to 3'): string (nullable = true)
#  |-- Variant protein name: string (nullable = true)
#  |-- Variant legacy name: string (nullable = true)
#  |-- rsID: string (nullable = true)
#  |-- # alleles in CFTR2: long (nullable = true)
#  |-- Allele frequency in CFTR2
# (of 142,036 identified variants)*: double (nullable = true)
#  |-- % pancreatic insufficient (patients with variant in trans with ACMG-PI variant): double (nullable = true)
#  |-- Variant final determination
# 17 March 2017
# (previous version): string (nullable = true)
#  |-- Variant final determination
# 6 December 2017
# (current version): string (nullable = true)
#  |-- Change from previous version?: string (nullable = true)
#  |-- snpId: string (nullable = true)

# %% [markdown]
# ## Read file with dbSNP info
# The following dataset was created from the SNP3D_PDB_GRCH37 dataset by mapping non-synonymous SNPs to human proteins with >= 95% sequence identity in the PDB.

# %%
dbsnp = dbSnpDataset.get_cached_dataset()
dbsnp.count()
# Out:
# 1171630

# %%
ds = ctfr2.join(dbsnp, ctfr2.snpId == dbsnp.snp_id)
ds.show()
# Out:
# +------------------------------------+--------------------+-------------------+-----------+------------------+-----------------------------------------------------------+-------------------------------------------------------------------------------+------------------------------------------------------------+-------------------------------------------------------------+-----------------------------+---------+---+---------+---------+----------+---------+----------+----------+----------+----------+-------+-------+-----------+--------------------+----------+------+---------+---------+----------+
# |Variant cDNA name
# (ordered 5' to 3')|Variant protein name|Variant legacy name|       rsID|# alleles in CFTR2|Allele frequency in CFTR2
# (of 142,036 identified variants)*|% pancreatic insufficient (patients with variant in trans with ACMG-PI variant)|Variant final determination
# 17 March 2017
# (previous version)|Variant final determination
# 6 December 2017
# (current version)|Change from previous version?|    snpId|chr|      pos|   snp_id|master_acc|master_gi|master_pos|master_res|master_var|    pdb_gi|pdb_res|pdb_pos|blast_ident|             clinsig|pdbChainId|tax_id|pdbResNum|uniprotId|uniprotNum|
# +------------------------------------+--------------------+-------------------+-----------+------------------+-----------------------------------------------------------+-------------------------------------------------------------------------------+------------------------------------------------------------+-------------------------------------------------------------+-----------------------------+---------+---+---------+---------+----------+---------+----------+----------+----------+----------+-------+-------+-----------+--------------------+----------+------+---------+---------+----------+
# |                           c.1721C>A|         p.Pro574His|              P574H|rs121908758|                25|                                       1.760117153397730...|                                                                           0.35|                                                         nan|                                                   CF-causing|                          Yes|121908758|  7|117230448|121908758| NP_000483| 90421313|       574|         P|         H|1132605083|      P|    574|      100.0|   Likely pathogenic|    5UAK.A|  9606|      574|   P13569|       574|
# |                c.720_741delAGGGA...|    p.Gly241GlufsX13|           852del22|rs121908804|                13|                                       9.152609197668197E-5|                                                                            1.0|                                                  CF-causing|                                                   CF-causing|                           No|121908804|  7|117175442|121908804| NP_000483| 90421313|       241|         G|         E|1132605083|      G|    241|      100.0|          Pathogenic|    5UAK.A|  9606|      241|   P13569|       241|
# |                           c.1021T>C|         p.Ser341Pro|              S341P|rs397508144|                23|                                       1.619307781125911...|                                                                          0.375|                                                  CF-causing|                                                   CF-causing|                           No|397508144|  7|117180305|397508144| NP_000483| 90421313|       341|         S|         P|1132605083|      S|    341|      100.0|          Pathogenic|    5UAK.A|  9606|      341|   P13569|       341|
# |                c.4036_4042delCTA...|    p.Leu1346MetfsX6|     4168delCTAAGCC|rs397508662|                 3|                                       2.112140584077276E-5|                                                                            1.0|                                                         nan|                                                   CF-causing|                          Yes|397508662|  7|117304814|397508662| NP_000483| 90421313|      1346|         L|         M|1132605083|      L|   1346|      100.0|                null|    5UAK.A|  9606|     1346|   P13569|      1346|
+----------+
# only showing top 20 rows

# %% [markdown]
# ## Filter by clinical significance

# %%
# if significance.value and not 'All' in significance.value:
#     ds = ds.filter(sig_query)
#     print("Results: ", ds.count())

# %%
# if field.value in ['pdbChainId', 'uniprotId']:
#     print("Filtered by query: ", query)
#     ds = ds.filter(query)
#     ds.show(5)

# %% [markdown]
# ### Show some sample results

# %%
ds.toPandas().head(20)
# Out:
#    Variant cDNA name\n(ordered 5' to 3') Variant protein name  \
# 0                              c.1721C>A          p.Pro574His
# 1     c.720_741delAGGGAGAATGATGATGAAGTAC     p.Gly241GlufsX13
# 2                              c.1021T>C          p.Ser341Pro
# 3                  c.4036_4042delCTAAGCC     p.Leu1346MetfsX6
# 4                               c.494T>C          p.Leu165Ser
# 5                            c.1692delA       p.Asp565MetfsX7
# 6                             c.1650delA      p.Gly551ValfsX8
# 7                              c.310delA      p.Arg104GlufsX3
# 8                      c.543_546delTAGT      p.Leu183PhefsX5
# 9                      c.859_863delAACTT     p.Asn287LysfsX19
# 10                             c.3485G>T         p.Arg1162Leu
# 11                             c.3485G>T         p.Arg1162Leu
# 12                             c.3485G>T         p.Arg1162Leu
# 13                             c.3154T>G         p.Phe1052Val
# 14                             c.3472C>T           p.Arg1158X
# 15                             c.3472C>T           p.Arg1158X
# 16                             c.3484C>T           p.Arg1162X
# 17                             c.3846G>A           p.Trp1282X
# 18                             c.3846G>A           p.Trp1282X
# 19                              c.958T>G          p.Leu320Val
#
#    Variant legacy name         rsID  # alleles in CFTR2  \
# 0                P574H  rs121908758                  25
# 1             852del22  rs121908804                  13
# 2                S341P  rs397508144                  23
# 3       4168delCTAAGCC  rs397508662                   3
# 4                L165S  rs397508736                  21
# 5             1824delA  rs193922505                   5
# 6             1782delA  rs397508251                   4
# 7              442delA  rs397508499                   7
# 8              675del4  rs397508750                   4
# 9              991del5  rs397508805                  15
# 10              R1162L    rs1800120                  16
# 11              R1162L    rs1800120                  16
# 12              R1162L    rs1800120                  16
# 13              F1052V  rs150212784                  34
# 14              R1158X   rs79850223                 179
# 15              R1158X   rs79850223                 179
# 16              R1162X   rs74767530                 651
# 17              W1282X   rs77010898                1726
# 18              W1282X   rs77010898                1726
# 19               L320V  rs144476686                   7
#
#     Allele frequency in CFTR2\n(of 142,036 identified variants)*  \
# 0                                            0.000176
# 1                                            0.000092
# 2                                            0.000162
# 3                                            0.000021
# 4                                            0.000148
# 5                                            0.000035
# 6                                            0.000028
# 7                                            0.000049
# 8                                            0.000028
# 9                                            0.000106
# 10                                           0.000113
# 11                                           0.000113
# 12                                           0.000113
# 13                                           0.000239
# 14                                           0.001260
# 15                                           0.001260
# 16                                           0.004583
# 17                                           0.012152
# 18                                           0.012152
# 19                                           0.000049
#
#     % pancreatic insufficient (patients with variant in trans with ACMG-PI variant)  \
# 0                                            0.350000
# 1                                            1.000000
# 2                                            0.375000
# 3                                            1.000000
# 4                                            0.368421
# 5                                            1.000000
# 6                                            1.000000
# 7                                            0.857143
# 8                                            1.000000
# 9                                            1.000000
# 10                                           0.384615
# 11                                           0.384615
# 12                                           0.384615
# 13                                           0.153846
# 14                                           0.989474
# 15                                           0.989474
# 16                                           0.973430
# 17                                           0.986499
# 18                                           0.986499
# 19                                           0.000000
#
#    Variant final determination\n17 March 2017\n(previous version)  \
# 0                                                 nan
# 1                                          CF-causing
# 2                                          CF-causing
# 3                                                 nan
# 4                                                 nan
# 5                                          CF-causing
# 6                                          CF-causing
# 7                                          CF-causing
# 8                                          CF-causing
# 9                                          CF-causing
# 10                                     Non CF-causing
# 11                                     Non CF-causing
# 12                                     Non CF-causing
# 13                       Varying clinical consequence
# 14                                         CF-causing
# 15                                         CF-causing
# 16                                         CF-causing
# 17                                         CF-causing
# 18                                         CF-causing
# 19                                                nan
#
#    Variant final determination\n6 December 2017\n(current version)  \
# 0                                          CF-causing
# 1                                          CF-causing
# 2                                          CF-causing
# 3                                          CF-causing
# 4                                          CF-causing
# 5                                          CF-causing
# 6                                          CF-causing
# 7                                          CF-causing
# 8                                          CF-causing
# 9                                          CF-causing
# 10                                     Non CF-causing
# 11                                     Non CF-causing
# 12                                     Non CF-causing
# 13                       Varying clinical consequence
# 14                                         CF-causing
# 15                                         CF-causing
# 16                                         CF-causing
# 17                                         CF-causing
# 18                                         CF-causing
# 19                               Unknown significance
#
#    Change from previous version?     ...          pdb_gi pdb_res  pdb_pos  \
# 0                            Yes     ...      1132605083       P      574
# 1                             No     ...      1132605083       G      241
# 2                             No     ...      1132605083       S      341
# 3                            Yes     ...      1132605083       L     1346
# 4                            Yes     ...      1132605083       L      165
# 5                             No     ...      1132605083       D      565
# 6                             No     ...      1132605083       G      551
# 7                             No     ...      1132605083       R      104
# 8                             No     ...      1132605083       L      183
# 9                             No     ...      1132605083       N      287
# 10                            No     ...      1132605083       R     1162
# 11                            No     ...      1132605083       R     1162
# 12                            No     ...      1132605083       R     1162
# 13                            No     ...      1132605083       F     1052
# 14                            No     ...      1132605083       R     1158
# 15                            No     ...      1132605083       R     1158
# 16                            No     ...      1132605083       R     1162
# 17                            No     ...      1132605083       W     1282
# 18                            No     ...      1132605083       W     1282
# 19                           Yes     ...      1132605083       L      320
#
#     blast_ident                 clinsig  pdbChainId  tax_id pdbResNum  \
# 0         100.0       Likely pathogenic      5UAK.A    9606       574
# 1         100.0              Pathogenic      5UAK.A    9606       241
# 2         100.0              Pathogenic      5UAK.A    9606       341
# 3         100.0                    None      5UAK.A    9606      1346
# 4         100.0                untested      5UAK.A    9606       165
# 5         100.0              Pathogenic      5UAK.A    9606       565
# 6         100.0              Pathogenic      5UAK.A    9606       551
# 7         100.0              Pathogenic      5UAK.A    9606       104
# 8         100.0              Pathogenic      5UAK.A    9606       183
# 9         100.0              Pathogenic      5UAK.A    9606       287
# 10        100.0  Uncertain significance      5UAK.A    9606      1162
# 11        100.0  Uncertain significance      5UAK.A    9606      1162
# 12        100.0  Uncertain significance      5UAK.A    9606      1162
# 13        100.0           drug-response      5UAK.A    9606      1052
# 14        100.0              Pathogenic      5UAK.A    9606      1158
# 15        100.0              Pathogenic      5UAK.A    9606      1158
# 16        100.0              Pathogenic      5UAK.A    9606      1162
# 17        100.0              Pathogenic      5UAK.A    9606      1282
# 18        100.0              Pathogenic      5UAK.A    9606      1282
# 19        100.0  Uncertain significance      5UAK.A    9606       320
#
#    uniprotId  uniprotNum
# 0     P13569         574
# 1     P13569         241
# 2     P13569         341
# 3     P13569        1346
# 4     P13569         165
# 5     P13569         565
# 6     P13569         551
# 7     P13569         104
# 8     P13569         183
# 9     P13569         287
# 10    P13569        1162
# 11    P13569        1162
# 12    P13569        1162
# 13    P13569        1052
# 14    P13569        1158
# 15    P13569        1158
# 16    P13569        1162
# 17    P13569        1282
# 18    P13569        1282
# 19    P13569         320
#
# [20 rows x 29 columns]

# %% [markdown]
# ## Aggregate data on the residue and chain level

# %%
ds = ds.groupBy("pdbChainId","pdbResNum","master_res","uniprotId").agg(collect_set("master_var").alias("master_var"),collect_set("clinsig").alias("clinsig"))
ds = ds.withColumn("master_var", concat_ws((""), ds.master_var))
ds = ds.withColumn("clinsig", concat_ws((","), ds.clinsig))
ds = ds.withColumn("snps", concat_ws(("->"), ds.master_res, ds.master_var))
ds = ds.drop("master_res")
ds = ds.groupBy("pdbChainId","uniprotId").agg(collect_list("pdbResNum").alias("pdbResNums"), \
                                              collect_list("snps").alias("snps"), \
                                              collect_list("clinsig").alias("clinsig"))

# %%
df = ds.toPandas()
df.head(20)
# Out:
#   pdbChainId uniprotId                                         pdbResNums  \
# 0     5UAK.A    P13569  [98, 349, 970, 525, 201, 334, 945, 560, 1371, ...
#
#                                                 snps  \
# 0  [Q->*PR, A->V, G->RS, Q->*, V->M, R->QW, S->L,...
#
#                                              clinsig
# 0  [Pathogenic,untested, Pathogenic, Pathogenic, ...

# %%
def view_modifications(df, cutoff_distance, *args):

    def view3d(show_bio_assembly=False, show_surface=False, show_labels=True, i=0):
        pdb_id, chain_id = df.iloc[i]['pdbChainId'].split('.')
        res_num = df.iloc[i]['pdbResNums']
        labels = df.iloc[i]['snps']
        sigs = df.iloc[i]['clinsig']
        
        # added '' for clinvar sig
        sig_dir = {'Benign':'green', 'Likely benign':'turquoise', 'Likely pathogenic':'palevioletred', \
                    'Pathogenic':'red', 'drug-response':'plum', 'untested':'white', \
                    'Uncertain significance': 'lightgray', 'other':'white', 'null':'white', '':'white'}
        
       # print header
        print ("PDB Id: " + pdb_id + " chain Id: " + chain_id)
        
        # print any specified additional columns from the dataframe
        for a in args:
            print(a + ": " + df.iloc[i][a])

        all_residues = {'resi': res_num, 'chain': chain_id}
        
        # select neigboring residues by distance
        surroundings = {'chain': chain_id, 'resi': res_num, 'byres': True, 'expand': cutoff_distance}
        
        viewer = py3Dmol.view(query='pdb:' + pdb_id, options={'doAssembly': show_bio_assembly})

        # polymer style
        viewer.setStyle({'cartoon': {'colorscheme': 'chain', 'width': 0.6, 'opacity':0.9}})

        # non-polymer style
        viewer.setStyle({'hetflag': True}, {'stick':{'radius': 0.3, 'singleBond': False}})
        
        # residues surrounding mutation positions
        viewer.addStyle(surroundings,{'stick':{'colorscheme':'orangeCarbon', 'radius': 0.15}})
        
        # mutation positions
        for label, res, sig in zip(labels, res_num, sigs):
            sig1 = sig.split(',')[0] # if multiple values, use the first one
            col = (sig_dir[sig1])
            mod_res = {'resi': res, 'chain': chain_id} 
            c_col = col + "Carbon"
            viewer.addStyle(mod_res, {'stick':{'colorscheme':c_col, 'radius': 0.2}})
            viewer.addStyle(mod_res, {'sphere':{'color':col, 'opacity': 0.6}})
                
            if show_labels:
                viewer.addLabel(label + " " + sig, {'fontSize':10,'fontColor':col,'backgroundColor':'ivory'}, {'resi': res, 'chain': chain_id})
        
        viewer.zoomTo(all_residues)
        
        if show_surface:
            viewer.addSurface(py3Dmol.SES,{'opacity':0.8,'color':'lightblue'})

        return viewer.show()
       
    s_widget = IntSlider(min=0, max=len(df)-1, description='Structure', continuous_update=False)
    
    return interact(view3d, show_bio_assembly=False, show_surface=False, show_labels=True, i=s_widget)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {return false;}

# %% [markdown]
# ## Visualize locations of missense mutations
# Mutated residues are rendered in as sticks and transparent spheres, and colored by ClinVar significance. Each mutation is labeled by the PDB residue number and ClinVar significance. Residues surrounding mutation sites (within 6 A) are rendered as thin orange sticks. Small molecules within the structure are rendered as gray sticks.

# %%
view_modifications(df, 6, 'uniprotId');
# Out:
# interactive(children=(Checkbox(value=False, description='show_bio_assembly'), Checkbox(value=False, descriptio…

# %%
def view_surface(df, cutoff_distance, *args):

    def view3d(show_bio_assembly=False, show_surface=False, show_labels=True, i=0):
        pdb_id, chain_id = df.iloc[i]['pdbChainId'].split('.')
        res_num = df.iloc[i]['pdbResNums']
        labels = df.iloc[i]['snps']
        sigs = df.iloc[i]['clinsig']
        
        sig_dir = {'Benign':'green', 'Likely benign':'turquoise', 'Likely pathogenic':'palevioletred', \
                   'Pathogenic':'red', 'drug-response':'plum', 'untested':'white', \
                   'Uncertain significance': 'lightgray', 'other':'white', 'null':'white'}
        
        # print header
        print ("PDB Id: " + pdb_id + " chain Id: " + chain_id)
        
        # print any specified additional columns from the dataframe
        for a in args:
            print(a + ": " + df.iloc[i][a])
            
        viewer = py3Dmol.view(query='pdb:' + pdb_id, options={'doAssembly': show_bio_assembly})

        all_residues = {'resi': res_num, 'chain': chain_id}
        
        # polymer style
        viewer.setStyle({'sphere': {'colorscheme': 'chain', 'opacity':0.6}})
        
        # non-polymer style
        viewer.setStyle({'hetflag': True}, {'stick':{'radius': 0.3, 'singleBond': False}})

        # mutation style
        for label, res, sig in zip(labels, res_num, sigs):
            sig1 = sig.split(',')[0] # if multiple values, use the first one
            col = (sig_dir[sig1])
            mod_res = {'resi': res, 'chain': chain_id} 
            viewer.setStyle(mod_res, {'sphere':{'color':col}})
        
            if show_labels:
                viewer.addLabel(label + " " + sig, {'fontSize':10,'fontColor':col,'backgroundColor':'ivory'}, {'resi': res, 'chain': chain_id})
        
        viewer.zoomTo(all_residues)        
        
        if show_surface:
            viewer.addSurface(py3Dmol.SES,{'opacity':0.8,'color':'lightblue'})

        return viewer.show()
       
    s_widget = IntSlider(min=0, max=len(df)-1, description='Structure', continuous_update=False)
    
    return interact(view3d, show_bio_assembly=False, show_surface=False, show_labels=True, i=s_widget)

# %%
view_surface(df, 6, 'uniprotId');
# Out:
# interactive(children=(Checkbox(value=False, description='show_bio_assembly'), Checkbox(value=False, descriptio…

# %%
spark.stop()
